# %% [markdown]
# # Изучение функций с помощью MatplotLib

# %%
import sys
sys.version_info
import  matplotlib.pyplot  as  plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# Цель задания - исследование функции
# $$\LARGE f(x) = \frac{x^{\beta} + \alpha^{\beta}}{x^{\beta} }$$
# при различных значениях $\alpha$ и $\beta$.
#
# Для каждой задачи необходимо:
#
# - Построить график (размер графика должен быть достаточным, чтобы визуально увидеть особенности изучаемых функций), график каждой функции должен быть одного цвета для одного значения $\alpha$ и $\beta$.
#
# - Подписать оси и заголовок
#
# - Создать легенду
#
# - Сохранить изображение в svg файл
#
# - Сделать и записать выводы о поведении графиков (можно использовать наводящие вопросы)
# ___________
#
# - Код не должен вызывать ошибки исполнения (например, из-за деления на 0 или корня из отрицательной величины)
#
# - Код должен выполняться (падение кода с ошибкой у проверяющего на python аналогичной версии - повод не зачесть все пункты соответствующей задачи)

# %% [markdown]
# ## Задача №1
#
# ### Часть 1
#
# Построить в общих осях графики для:
#
# - $\alpha = 1, \beta = 1$
#
# - $\alpha = 2, \beta = 1$
#
# - $\alpha = 1, \beta = 2$

# %%
def f(alfa,beta,x):
    z = []
    for i in x:
        fx = (i**beta+alfa**beta)/(i**beta)
        #print(fx)
        z.append(fx)
    return z


x = np.arange(-4,4,0.25)
fig = plt.figure(figsize=(13,8))

plt.plot(x, list(f(1,1,x)), 'r', label=u'f(x) alfa = 1 beta = 1')
plt.plot(x, list(f(2,1,x)), 'g', label=u'f(x) alfa = 1 beta = 2')
plt.plot(x, list(f(1,2,x)), 'b', label=u'f(x) alfa = 2 beta = 1')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Title')

plt.legend();

plt.show()
fig.savefig('1.svg')

# все выводы видны из графика
# Out:
# /Users/aleksey/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in double_scalars
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Часть 2
#
# Построить в общих осях графики для $x>0$.
#
# На том же графике сделать 2 врезки, демонстрирующие поведение графиков на 2 интервалах:
#
# - для малых x
#
# - для больших x
#
# Необходимо продемонстрировать возможность (или невозможность) пересечений и стремление функций.
#
# Цвет линий на врезках и основном графике должен быть одинаковым для одних и тех же значений $\alpha$ и $\beta$.

# %%
x = np.arange(0,50,0.25)
fig = plt.figure(figsize=(13,8))
axes1 = fig.add_axes([0,0,1,1])
axes1.plot(x, list(f(1,1,x)), 'r', label=u'f(x) alfa = 1 beta = 1')
axes1.plot(x, list(f(2,1,x)), 'g', label=u'f(x) alfa = 1 beta = 2')
axes1.plot(x, list(f(1,2,x)), 'b', label=u'f(x) alfa = 2 beta = 1')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Title')


x = np.arange(0,3,0.25)
axes2 = fig.add_axes([1.2,0.6,0.4,0.4])
axes2.plot(x, list(f(1,1,x)), 'r', label=u'f(x) alfa = 1 beta = 1')
axes2.plot(x, list(f(2,1,x)), 'g', label=u'f(x) alfa = 1 beta = 2')
axes2.plot(x, list(f(1,2,x)), 'b', label=u'f(x) alfa = 2 beta = 1')

x = np.arange(0,100,0.25)
axes3 = fig.add_axes([1.2,0.0,0.4,0.4])
axes3.plot(x, list(f(1,1,x)), 'r', label=u'f(x) alfa = 1 beta = 1')
axes3.plot(x, list(f(2,1,x)), 'g', label=u'f(x) alfa = 1 beta = 2')
axes3.plot(x, list(f(1,2,x)), 'b', label=u'f(x) alfa = 2 beta = 1')

axes1.legend()
axes2.legend()
axes3.legend()
plt.legend()

plt.show()
# Out:
# /Users/aleksey/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in double_scalars
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Часть 3
#
# Построить в общих осях графики для $x<0$.
#
# На том же графике сделать 1 врезку, демонстрирующую поведение графиков при удалении x от 0 к $-\infty$.
#
# Необходимо продемонстрировать возможность (или невозможность) пересечений и стремление функций. Так же нанесите на графики прямую f(x) = 0.
#
# Цвет линий на врезках и основном графике должен быть одинаковым для одних и тех же значений $\alpha$ и $\beta$.

# %%
x = np.arange(-30,0,0.25)
fig = plt.figure(figsize=(13,8))
axes1 = fig.add_axes([0,0,1,1])
axes1.plot(x, list(f(1,1,x)), 'r', label=u'f(x) alfa = 1 beta = 1')
axes1.plot(x, list(f(2,1,x)), 'g', label=u'f(x) alfa = 1 beta = 2')
axes1.plot(x, list(f(1,2,x)), 'b', label=u'f(x) alfa = 2 beta = 1')
axes1.plot([-30,0], [0,0], 'b', label=u'f(x) alfa = 2 beta = 1')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Title')

axes1.legend()
plt.legend()

plt.show()

# %% [markdown]
# Сделайте выводы о поведении графиков при различных значениях $\alpha$ и $\beta$.
#
# Изучите возможности пересечения и то к чему стремятся кривые.
#
# Сделайте выводы о возрастании/убывании.

# %% [markdown]
# ## Задача №2
#
# Построить в общих осях графики для:
#
# - $\alpha = 1, \beta = 0$
#
# - $\alpha = 0, \beta = 0$
#
# - $\alpha = 0, \beta = 1$
#
# - $\alpha = 0, \beta = 2$
#
# - $\alpha = 1, \beta = -1$
#
# - $\alpha = 2, \beta = -1$
#
# Сделайте выводы о поведении графиков

# %%
x = np.arange(-4,4,0.25)
fig = plt.figure(figsize=(13,8))

plt.plot(x, list(f(1,0,x)), 'r', label=u'f(x) alfa = 1 beta = 0')
plt.plot(x, list(f(0,0,x)), 'g', label=u'f(x) alfa = 0 beta = 0')
plt.plot(x, list(f(0,1,x)), 'b', label=u'f(x) alfa = 0 beta = 1')
plt.plot(x, list(f(0,2,x)), 'y', label=u'f(x) alfa = 0 beta = 2')
plt.plot(x, list(f(1,-1,x)), 'm', label=u'f(x) alfa = 1 beta = -1')
plt.plot(x, list(f(2,-1,x)), 'k', label=u'f(x) alfa = 2 beta = -1')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Title')

plt.legend();

plt.show()
# Out:
# /Users/aleksey/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.
# /Users/aleksey/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in double_scalars
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Задача №3
#
# Построить в общих осях графики для:
#
# - $\alpha = 1, \beta = 0.5$
#
# - $\alpha = 1, \beta = -0.5$
#
# - $\alpha = 1, \beta = -1.5$
#
# Сделайте выводы о поведении графиков, включая возрастание/убывание и выпуклость/вогнутость

# %%
x = np.arange(-4,4,0.25)
fig = plt.figure(figsize=(13,8))

plt.plot(x, list(f(1,0.5,x)), 'r', label=u'f(x) alfa = 1 beta = 0.5')
plt.plot(x, list(f(1,-0.5,x)), 'g', label=u'f(x) alfa = 1 beta = -0.5')
plt.plot(x, list(f(1,-1.5,x)), 'b', label=u'f(x) alfa = 1 beta = -1.5')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Title')

plt.legend();

plt.show()
# Out:
# /Users/aleksey/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.
# /Users/aleksey/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in double_scalars
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Задача №4
#
# В результате выполнения предыдущей задачи, вы вероятно заметите, что все графики с $\alpha=1$ проходят через общую точку (1, 2).
#
# Постройте в одном ряду 3 графика, чтобы убедиться в выводах, сделанных по результатам предыдущей задачи.
#
# Каждый график будет содержать 4 кривые. 2 общих:
#
# - $\alpha = 1, \beta = 0$ (в качестве цвета попробуйте использовать 'b--')
#
# - $\alpha = 1, \beta = -1$ (в качестве цвета попробуйте использовать 'r--')
#
# И 2 уникальных для каждого графика:
#
# 1. $\alpha = 1, \beta = 0.5$ и $\alpha = 1, \beta = 0.8$
#
# 2. $\alpha = 1, \beta = -0.5$ и $\alpha = 1, \beta = -0.8$
#
# 3. $\alpha = 1, \beta = -1.5$ и $\alpha = 1, \beta = -2.5$
#
# Не забудьте добавить легенду на каждый график. Для этого может потребоваться вызвать метод legend() для каждого объекта осей.
#
# Для того чтобы задать общий заголовок для всех 3 графиков используйте метод https://matplotlib.org/api/_as_gen/matplotlib.pyplot.suptitle.html

# %%
x = np.arange(-4,4,0.25)

fig, axes = plt.subplots(1,3,figsize=(20,5))

axes[0].plot(x, list(f(1,0,x)), 'b--', label=u'f(x) alfa = 1 beta = 0')
axes[0].plot(x, list(f(1,-1,x)), 'r--', label=u'f(x) alfa = 1 beta = -1')
axes[0].legend();
axes[0] = fig.add_axes([0.14, 1, 0.2, 0.2])
axes[0].plot(x, list(f(1,0.5,x)), 'y--', label=u'f(x) alfa = 1 beta = 0.5')
axes[0].plot(x, list(f(1,0.8,x)), 'k--', label=u'f(x) alfa = 1 beta = 0.8')
axes[0].legend();

axes[1].plot(x, list(f(1,0,x)), 'b--', label=u'f(x) alfa = 1 beta = 0')
axes[1].plot(x, list(f(1,-1,x)), 'r--', label=u'f(x) alfa = 1 beta = -1')
axes[1].legend();
axes[1] = fig.add_axes([0.4, 1, 0.2, 0.2])
axes[1].plot(x, list(f(1,-0.5,x)), 'y--', label=u'f(x) alfa = 1 beta = -0.5')
axes[1].plot(x, list(f(1,-0.8,x)), 'k--', label=u'f(x) alfa = 1 beta = -0.8')
axes[1].legend();

axes[2].plot(x, list(f(1,0,x)), 'b--', label=u'f(x) alfa = 1 beta = 0')
axes[2].plot(x, list(f(1,-1,x)), 'r--', label=u'f(x) alfa = 1 beta = -1')
axes[2].legend();
axes[2] = fig.add_axes([0.68, 1, 0.2, 0.2])
axes[2].plot(x, list(f(1,-1.5,x)), 'y--', label=u'f(x) alfa = 1 beta = -1.5')
axes[2].plot(x, list(f(1,-2.5,x)), 'k--', label=u'f(x) alfa = 1 beta = -2.5')
axes[2].legend();

fig.suptitle('title', fontsize=12)
plt.show()
# Out:
# /Users/aleksey/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in double_scalars
#   after removing the cwd from sys.path.
# /Users/aleksey/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.
