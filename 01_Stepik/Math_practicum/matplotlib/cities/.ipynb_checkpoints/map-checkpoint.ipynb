# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots()#figsize=(13, 6.5))

with open('world.jpg', 'rb') as map_file:
    map_img = plt.imread(map_file)

axes.imshow(map_img)
center = (1280//2, 644//2)
plt.plot([center[0]], [center[1]], 'r*')
plt.plot([center[0] + 200], [center[1] - 100], 'r*')
plt.show()
